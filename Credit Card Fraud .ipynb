# %%
import pandas as pd
import seaborn as sns
sns.__version__
# Out:
# '0.11.0'

# %%
df = pd.read_csv('/Users/shriyagupta/Downloads/creditcard 2.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
data_descp = df.describe()
data_descp
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
# Relationship with target variable
#num with cat corr with target - sns_bar dist with diff chi square- wth binnig ; random forest

# %%
#Outliers:
data = df.iloc[:,1:29]
data.head()

# 1. Boxplot - normal dist
sns.boxplot(data=data, orient='h')
sns.despine(left=True, top=True, right=True, trim=True, offset=10)
sns.set(rc={'figure.figsize':(30,40)})

# %%
#2. IQR
for i in data_descp.columns[1:30]:
    print(i)
    IQR = 1.5*(data_descp.loc['75%',i] - data_descp.loc['25%',i])
    print(df[i] < (data_descp.loc['25%',i] - IQR))
    print(df[i] > data_descp.loc['75%',i] + IQR)
# Out:
# V1
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18         True
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 284777    False
# 284778    False
# 284779    False
# 284780    False
# 284781    False
# 284782    False
# 284783    False
# 284784    False
# 284785    False
# 284786    False
# 284787    False
# 284788    False
# 284789    False
# 284790    False
# 284791    False
# 284792    False
# 284793    False
# 284794    False
# 284795     True
# 284796    False
# 284797    False
# 284798    False
# 284799    False
# 284800    False
# ...

# %%
# Correlation - Multicolliearity
df1=df.iloc[:,1:30]
df1.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col1 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col2 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_99b2bc2c_3ce7_11eb_8865_88e9fe5020ebrow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
sns.displot(df, x='V1', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V2', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V3', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V4', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V5', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V6', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V7', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V8', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V9', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V10', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V11', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V12', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V13', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V14', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V15', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V16', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V17', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V18', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V19', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V20', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V21', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V22', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V23', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V24', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V25', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V26', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V27', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='V28', kind='kde', hue='Class'  )

# %%
sns.displot(df, x='Amount', kind='kde', hue='Class'  )

# %%
#random forest, decision trees
sns.displot?

# %%
penguins = sns.l 
oad_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.__version__
